# %%
from pandas import read_csv
import numpy as np

# %%
df = read_csv("lectures/international-airline-passengers.csv", usecols = [1])
df.describe()
# Out:
#        International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# count                                         144.000000
# mean                                          280.298611
# std                                           119.966317
# min                                           104.000000
# 25%                                           180.000000
# 50%                                           265.500000
# 75%                                           360.500000
# max                                           622.000000

# %%
values = df.values.astype('float32')
values.shape
# Out:
# (144, 1)

# %%
train_size = int((values.shape[0] * 0.67))
test_size = values.shape[0] - train_size
train = values[0:train_size]
test = values[train_size:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
train = scaler.fit_transform(train)
test = scaler.transform(test)

# %%
def create_dataset(data, k):
    dataX, dataY = [], []
    for i in range(data.shape[0] - k):
        x = data[i:i+k, 0]
        y = data[i+k, 0]
        dataX.append(x)
        dataY.append(y)
    return np.array(dataX), np.array(dataY)

# %%
look_back = 12
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))
trainX.shape
# Out:
# (84, 12, 1)

# %% [markdown]
# ### Setting up the model

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
# Out:
# WARNING:tensorflow:From s:\miniconda\envs\tf\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = Sequential()
model.add(SimpleRNN(4, input_shape = (look_back, 1)))
model.add(Dense(64, activation = 'relu'))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(trainX, trainY, epochs = 10, batch_size = 1)
# Out:
# WARNING:tensorflow:From s:\miniconda\envs\tf\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From s:\miniconda\envs\tf\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 84/84 [==============================] - 1s 2ms/step - loss: 0.0387
# Epoch 2/10
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0162
# Epoch 3/10
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0134
# Epoch 4/10
# 84/84 [==============================] - 0s 2ms/step - loss: 0.0121
# Epoch 5/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0123
# Epoch 6/10
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0118
# Epoch 7/10
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0116
# Epoch 8/10
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 9/10
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 10/10
# 84/84 [==============================] - 0s 1ms/step - loss: 0.0109

# %%
testPredict = model.predict(testX)
testPredict = scaler.inverse_transform(testPredict).ravel()

trainPredict = model.predict(trainX)
trainPredict = scaler.inverse_transform(trainPredict).ravel()

testTrue = scaler.inverse_transform([testY]).ravel()
trainTrue = scaler.inverse_transform([trainY]).ravel()

testPredict.shape, testTrue.shape
# Out:
# 2/2 [==============================] - 0s 2ms/step
# 3/3 [==============================] - 0s 2ms/step
# ((36,), (36,))

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(trainTrue, c = 'g')
plt.plot(trainPredict, c = 'b')
plt.show()

# %%
combinedPredicted = np.concatenate((trainPredict, testPredict))
combinedTrue = np.concatenate((trainTrue, testTrue))
plt.plot(combinedTrue, c = 'g')
plt.plot(combinedPredicted, c = 'b')
plt.show()

# %%
from sklearn.metrics import r2_score
r2_score(combinedTrue, combinedPredicted)
# Out:
# 0.7303926663784516
